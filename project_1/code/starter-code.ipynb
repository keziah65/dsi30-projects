# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# This project aims to explore trends in SAT and ACT participation and score data by state in 2017-2019 and make recommendations to increase SAT participation rates.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
#
# SAT
# ACT

# %% [markdown]
# ## Executive summary
# SAT and ACT are standardized exams that are frequently used in the United States for determining entrance to colleges.  As the SAT and ACT are equally challenging, most colleges don't favor one test over another when choosing applicants. The SAT test, however, predominates in some States, while the ACT test holds the majority of the states for a variety of reasons.
#
# In recent years, the ACT has outperformed the SAT in terms of participation. In an effort to keep up with rising ACT participation rates across the United States, the redesigned SAT format was introduced in March 2016. The SAT underwent some significant design changes as part of an effort by the College Board to make the exam more relevant.  In order to raise SAT participation rates in the future, this project intends to identify relevant trends and approaches that the College Board might use to boost SAT takers by utilizing the data on SAT and ACT participation and score by state from 2017 to 2019.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Ans:**
# Chosen datasets:
# - act_2017.csv: 2017 ACT Scores by State
# - act_2018.csv: 2018 ACT Scores by State
# - act_2019.csv: 2019 ACT Scores by State
# - sat_2017.csv: 2017 SAT Scores by State
# - sat_2018.csv: 2018 SAT Scores by State
# - sat_2019.csv: 2019 SAT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_mean(lst):
    sum_lst = 0
    for i in lst:
        sum_lst += i
    return sum_lst/len(lst)

# %%
#Testing the function:
lst = [1,2,3]
calculate_mean(lst)
# Out:
# 2.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_std(lst):
    mean = calculate_mean(lst)
    count = 0 
    n = len(lst)
    for num in lst:
        count += (num - mean)**2
    return (((1/n)*count)**0.5)

# %%
#Testing the function:
calculate_std(lst)
# Out:
# 0.816496580927726

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
import numpy as np
def str_to_float(my_string):
    try: 
        my_string = float(my_string.split('%')[0])/100
    except:
        my_string = np.nan    #creating exception to non-numerical value inside my_string
    return my_string

# %%
#Testing the function:
str_to_float('-')
# Out:
# nan

# %%
#Testing the function:
str_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
pwd
# Out:
# 'C:\\Users\\kezia\\Documents\\GA\\my_materials\\project_1\\code'

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### 2017 Data Import and Cleaning

# %%
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# ### 1. Display the data

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# ### 2. Check for missing  values

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.shape
# Out:
# (52, 7)

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# **Answer:**
# - sat_2017 dataset contains 51 rows and 5 columns. There are no null values in any columns.
# - act_2017 dataset contains 52 rows and 7 columns. There are no null values in any columns.

# %% [markdown]
# ### 3. Check for any obvious issues with the observations

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# We should note that each section in SAT is scored between 200-800.
# However, we could see from the table above that the minimum score for the Math section is 52.
# Thus, we should try to check which row contains this value.

# %%
#to check the states with Math score below minimum possible value of 200 in the sat_2017 dataset:
sat_2017[sat_2017['Math']<200]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# We should also note that each ACT section, and the overall composite score, are scored between 1 and 36. The min and max value for English, Math, Reading and Science are within this range. However, there seems to be an outlier which is the minimum score for Science that is 2.3.

# %%
act_2017[act_2017['Science']==2.3]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %% [markdown]
# As we need to make sure that all the data in each column has the correct data types, we realized that
# the data in column 'Composite' are strings but not floats. While trying to change the data type for
# 'Composite' column, we may find that there is a typo in row 51, where the value for 'Composite' is
# written as '20.2x'

# %%
act_2017.loc[51]['Composite']
# Out:
# '20.2x'

# %% [markdown]
# ###  4. Fix any errors identified in steps 2-3

# %% [markdown]
# We can identify the correct values for the errors identified at step 3 from the originial source of the data:
# - [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State ([source](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/))
# - [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State ([source](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows))

# %%
#sat_2017: fix the error in Maryland's Math Score:
sat_2017.loc[20, 'Math'] = 524

#act_2017: fix the error in Maryland's Science Score:
act_2017.loc[21, 'Science']= 23.2

#act_2017: fix the error in Wyoming's Composite Score:
act_2017.loc[51, 'Composite'] = act_2017.loc[51, 'Composite'].split('x')[0]

# %% [markdown]
# ### 5. Display the Data Types

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# **Answer:**
# - sat_2017 data types:
#     - object (str or mixed): ['State', 'Participation']
#         - 'Participation' column contains mixed numeric and non-numeric values. We should convert it            to numerical value(float data type) so that we can use this data for analysis.
#     - int64 (int) : ['Evidence-Based Reading and Writing', 'Math', 'Total']
#
#
# - act_2017 data types:
#     - object (str or mixed) : ['State', 'Participation', 'Composite']
#         - 'Participation' and 'Composite' columns contain mixed numeric and non-numeric values. We              should convert it to numerical value(float data type) so that we can use this data for                analysis.
#     - float64 (float) : ['English', 'Math', 'Reading', 'Science']

# %% [markdown]
# ### 6. Fix Incorrect Data Types

# %%
#Convert sat_2017['Participation'] values from string to float
sat_2017['Participation'] = sat_2017['Participation'].map(str_to_float)

# %%
#To check that the data type for 'Participation' column has been changed to float:
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
#We do the same for act_2017 dataset:
act_2017['Participation'] = act_2017['Participation'].map(str_to_float)
#act_2017['Composite'] = act_2017['Composite'].map(float(i))

# %%
act_2017['Composite'] = act_2017['Composite'].map(lambda value: float(value))

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# ### 7. Rename Columns

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
#Rename the columns for sat_2017 and act_2017 datasets
sat_2017.columns = ['state', 'sat17_participation', 'sat17_reading_writing', 'sat17_math', 'sat17_total']
act_2017.columns = ['state', 'act17_participation', 'act17_english', 'act17_math', 'act17_reading',
                    'act17_science', 'act17_composite']

# %% [markdown]
# ### 8. Drop unnecessary rows

# %% [markdown]
# We can remove the extra row which contains the national average in act_2017.

# %%
act_2017.drop(0, inplace = True)

# %%
act_2017.head()
# Out:
#         state  act17_participation  act17_english  act17_math  act17_reading  \
# 1     Alabama                 1.00           18.9        18.4           19.7
# 2      Alaska                 0.65           18.7        19.8           20.4
# 3     Arizona                 0.62           18.6        19.8           20.1
# 4    Arkansas                 1.00           18.9        19.0           19.7
# 5  California                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4
# 5           22.2             22.8

# %% [markdown]
# ### 9. Merge dataframes

# %%
combined_2017 = pd.merge(left = sat_2017, right = act_2017, on = 'state')
combined_2017.head()
# Out:
#         state  sat17_participation  sat17_reading_writing  sat17_math  \
# 0     Alabama                 0.05                    593         572
# 1      Alaska                 0.38                    547         533
# 2     Arizona                 0.30                    563         553
# 3    Arkansas                 0.03                    614         594
# 4  California                 0.53                    531         524
#
#    sat17_total  act17_participation  act17_english  act17_math  act17_reading  \
# 0         1165                 1.00           18.9        18.4           19.7
# 1         1080                 0.65           18.7        19.8           20.4
# 2         1116                 0.62           18.6        19.8           20.1
# 3         1208                 1.00           18.9        19.0           19.7
# 4         1055                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite
# 0           19.4             19.2
# 1           19.9             19.8
# 2           19.8             19.7
# 3           19.5             19.4
# 4           22.2             22.8

# %%
#Reset index
combined_2017.reset_index(drop = True, inplace = True)

# %%
combined_2017.head()
# Out:
#         state  sat17_participation  sat17_reading_writing  sat17_math  \
# 0     Alabama                 0.05                    593         572
# 1      Alaska                 0.38                    547         533
# 2     Arizona                 0.30                    563         553
# 3    Arkansas                 0.03                    614         594
# 4  California                 0.53                    531         524
#
#    sat17_total  act17_participation  act17_english  act17_math  act17_reading  \
# 0         1165                 1.00           18.9        18.4           19.7
# 1         1080                 0.65           18.7        19.8           20.4
# 2         1116                 0.62           18.6        19.8           20.1
# 3         1208                 1.00           18.9        19.0           19.7
# 4         1055                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite
# 0           19.4             19.2
# 1           19.9             19.8
# 2           19.8             19.7
# 3           19.5             19.4
# 4           22.2             22.8

# %% [markdown]
# ### 10. Perform any additional cleaning that you feel is necessary

# %% [markdown]
# (skipped)

# %% [markdown]
# ### 11. Save your cleaned and merged dataframes as csv files

# %%
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ### 2018 Data Import and Cleaning

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %% [markdown]
# ### 1. Display the data

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %% [markdown]
# ### 2. Check for missing values

# %%
sat_2018.shape
# Out:
# (51, 5)

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2018.shape
# Out:
# (52, 3)

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# **Comments:** no missing values

# %% [markdown]
# ### 3. Check for any obvious issues with the observations

# %%
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
act_2018.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %% [markdown]
# **Comments:** We have checked the summary statictics for both datasets are within the possible range
#     of values, we can also see that the min and max values are within the possible range as well.

# %% [markdown]
# ###  4. Fix any errors identified in steps 2-3

# %% [markdown]
# (no errors identified)

# %% [markdown]
# ### 5. Display the Data Types

# %%
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %% [markdown]
# ### 6. Fix Incorrect Data Types

# %%
sat_2018['Participation'] = sat_2018['Participation'].map(str_to_float)
act_2018['Participation'] = act_2018['Participation'].map(str_to_float)

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# ### Answer:
# - sat_2018 dataset contains 51 rows and 5 columns. There are no null values in any columns.
# - act_2018 dataset contains 52 rows and 3 columns. There are no null values in any columns.

# %% [markdown]
# ### 7. Rename Columns

# %%
sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
act_2018.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
#Rename the columns for sat_2018 and act_2018 datasets
sat_2018.columns = ['state', 'sat18_participation', 'sat18_reading_writing', 'sat18_math', 'sat18_total']
act_2018.columns = ['state', 'act18_participation', 'act18_composite']

# %% [markdown]
# ### 8. Drop unnecessary rows

# %% [markdown]
# We can remove the extra row of national summary from both sat_2018 and act_2018 (if there are any)

# %%
sat_2018[sat_2018['state']=='National']
# Out:
# Empty DataFrame
# Columns: [state, sat18_participation, sat18_reading_writing, sat18_math, sat18_total]
# Index: []

# %%
act_2018[act_2018['state']=='National']
# Out:
# Empty DataFrame
# Columns: [state, act18_participation, act18_composite]
# Index: []

# %% [markdown]
# There are no extra rows needed to be removed.

# %% [markdown]
# ### 9. Merge dataframes

# %% [markdown]
# Before we merge the dataframes based on states, we should check whether sat_2018 and act_2018 contain any different naming conventions.

# %%
act_2018[act_2018['state']=='District of columbia']
# Out:
#                   state  act18_participation  act18_composite
# 8  District of columbia                 0.32             23.6

# %% [markdown]
# We need to make sure that all the States name is in capital letter, so that we can merge the values properly accross different dataframes.

# %%
act_2018.loc[8,'state'] = 'District of Columbia'

# %%
combined_2018 = pd.merge(left = sat_2018, right = act_2018, on = 'state')
combined_2018.shape
# Out:
# (52, 7)

# %%
#Reset index
combined_2018.reset_index(drop = True, inplace = True)
combined_2018.head()
# Out:
#         state  sat18_participation  sat18_reading_writing  sat18_math  \
# 0     Alabama                 0.06                    595         571
# 1      Alaska                 0.43                    562         544
# 2     Arizona                 0.29                    577         572
# 3    Arkansas                 0.05                    592         576
# 4  California                 0.60                    540         536
#
#    sat18_total  act18_participation  act18_composite
# 0         1166                 1.00             19.1
# 1         1106                 0.33             20.8
# 2         1149                 0.66             19.2
# 3         1169                 1.00             19.4
# 4         1076                 0.27             22.7

# %% [markdown]
# ### 10. Perform any additional cleaning that you feel is necessary

# %% [markdown]
# (skipped)

# %% [markdown]
# ### 11. Save your cleaned and merged dataframes as csv files

# %%
combined_2018.to_csv('../data/combined_2018.csv')

# %% [markdown]
# ### 2019 Data Import and Cleaning

# %%
sat_2019 = pd.read_csv('../data/sat_2019.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')

# %% [markdown]
# ### 1. Display the data

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %% [markdown]
# ### 2. Check for missing values

# %%
sat_2019.shape
# Out:
# (53, 5)

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
act_2019.shape
# Out:
# (52, 3)

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# ### Answer:
# - sat_2019 dataset contains 53 rows and 5 columns. There are no null values in any columns.
# - act_2019 dataset contains 52 rows and 3 columns. There are no null values in any columns.

# %% [markdown]
# ### 3. Check for any obvious issues with the observations

# %%
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %% [markdown]
# **Comments:** We have checked the summary statictics for both datasets are within the possible range
#     of values, we can also see that the min and max values are within the possible range as well.

# %% [markdown]
# ###  4. Fix any errors identified in steps 2-3

# %% [markdown]
# (no errors identified)

# %% [markdown]
# ### 5. Display the Data Types

# %%
sat_2019.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
act_2019.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %% [markdown]
# ### 6. Fix Incorrect Data Types

# %%
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(str_to_float)
act_2019['Participation'] = act_2019['Participation'].map(str_to_float)

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  51 non-null     float64
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.2+ KB

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# ### 7. Rename Columns

# %%
sat_2019.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
act_2019.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
#Rename the columns for sat_2018 and act_2018 datasets
sat_2019.columns = ['state', 'sat19_participation', 'sat19_reading_writing', 'sat19_math', 'sat19_total']
act_2019.columns = ['state', 'act19_participation', 'act19_composite']

# %% [markdown]
# ### 8. Drop unnecessary rows

# %% [markdown]
# We can remove the extra row of national summary from both sat_2019 and act_2019 (if there are any).

# %%
sat_2019[sat_2019['state']=='National']
# Out:
# Empty DataFrame
# Columns: [state, sat19_participation, sat19_reading_writing, sat19_math, sat19_total]
# Index: []

# %%
act_2019[act_2019['state']=='National']
# Out:
#        state  act19_participation  act19_composite
# 51  National                 0.52             20.7

# %%
act_2019.drop(51, inplace = True)

# %% [markdown]
# ### 9. Merge dataframes

# %%
combined_2019 = pd.merge(left = sat_2019, right = act_2019, on = 'state')
combined_2019.head()
# Out:
#         state  sat19_participation  sat19_reading_writing  sat19_math  \
# 0     Alabama                 0.07                    583         560
# 1      Alaska                 0.41                    556         541
# 2     Arizona                 0.31                    569         565
# 3    Arkansas                 0.06                    582         559
# 4  California                 0.63                    534         531
#
#    sat19_total  act19_participation  act19_composite
# 0         1143                 1.00             18.9
# 1         1097                 0.38             20.1
# 2         1134                 0.73             19.0
# 3         1141                 1.00             19.3
# 4         1065                 0.23             22.6

# %%
#Reset index
combined_2019.reset_index(drop = True, inplace = True)
combined_2019.head()
# Out:
#         state  sat19_participation  sat19_reading_writing  sat19_math  \
# 0     Alabama                 0.07                    583         560
# 1      Alaska                 0.41                    556         541
# 2     Arizona                 0.31                    569         565
# 3    Arkansas                 0.06                    582         559
# 4  California                 0.63                    534         531
#
#    sat19_total  act19_participation  act19_composite
# 0         1143                 1.00             18.9
# 1         1097                 0.38             20.1
# 2         1134                 0.73             19.0
# 3         1141                 1.00             19.3
# 4         1065                 0.23             22.6

# %% [markdown]
# ### 10. Perform any additional cleaning that you feel is necessary

# %% [markdown]
# (skipped)

# %% [markdown]
# ### 11. Save your cleaned and merged dataframes as csv files

# %%
combined_2019.to_csv('../data/combined_2019.csv')

# %% [markdown]
# ### Combine data from 2017, 2018, 2019 into a single dataframe

# %%
#We join the 3 dataframes based on the 'state' column
combined_1718 = pd.merge(combined_2017, combined_2018, on='state')
combined_all = pd.merge(combined_1718, combined_2019, on='state')
combined_all.head()
# Out:
#         state  sat17_participation  sat17_reading_writing  sat17_math  \
# 0     Alabama                 0.05                    593         572
# 1      Alaska                 0.38                    547         533
# 2     Arizona                 0.30                    563         553
# 3    Arkansas                 0.03                    614         594
# 4  California                 0.53                    531         524
#
#    sat17_total  act17_participation  act17_english  act17_math  act17_reading  \
# 0         1165                 1.00           18.9        18.4           19.7
# 1         1080                 0.65           18.7        19.8           20.4
# 2         1116                 0.62           18.6        19.8           20.1
# 3         1208                 1.00           18.9        19.0           19.7
# 4         1055                 0.31           22.5        22.7           23.1
#
#    act17_science  ...  sat18_math  sat18_total  act18_participation  \
# 0           19.4  ...         571         1166                 1.00
# 1           19.9  ...         544         1106                 0.33
# 2           19.8  ...         572         1149                 0.66
# 3           19.5  ...         576         1169                 1.00
# 4           22.2  ...         536         1076                 0.27
#
#    act18_composite  sat19_participation  sat19_reading_writing  sat19_math  \
# 0             19.1                 0.07                    583         560
# 1             20.8                 0.41                    556         541
# 2             19.2                 0.31                    569         565
# 3             19.4                 0.06                    582         559
# 4             22.7                 0.63                    534         531
#
#    sat19_total  act19_participation  act19_composite
# 0         1143                 1.00             18.9
# 1         1097                 0.38             20.1
# 2         1134                 0.73             19.0
# 3         1141                 1.00             19.3
# 4         1065                 0.23             22.6
#
# [5 rows x 23 columns]

# %%
#Checking whether there are duplicates of column
combined_all.columns
# Out:
# Index(['state', 'sat17_participation', 'sat17_reading_writing', 'sat17_math',
#        'sat17_total', 'act17_participation', 'act17_english', 'act17_math',
#        'act17_reading', 'act17_science', 'act17_composite',
#        'sat18_participation', 'sat18_reading_writing', 'sat18_math',
#        'sat18_total', 'act18_participation', 'act18_composite',
#        'sat19_participation', 'sat19_reading_writing', 'sat19_math',
#        'sat19_total', 'act19_participation', 'act19_composite'],
#       dtype='object')

# %%
#Save the combined_all dataframe to csv
combined_all.to_csv('../data/combined_all.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |        Feature        |   Type  |    Range   | Dataset      |                             Description                            |
# |:---------------------:|:-------:|:----------:|--------------|:------------------------------------------------------------------:|
# | state                 | object  | all states | combined_all | name of US states                                                  |
# | sat17_participation   | float64 | 0-1        | combined_all | State SAT participation rate in 2017                               |
# | sat17_reading_writing | int64   | 200-800    | combined_all | State average SAT Evidence-Based Reading and Writing score in 2017 |
# | sat17_math            | int64   | 200-800    | combined_all | State average SAT Math score in 2017                               |
# | sat17_total           | int64   | 400-1600   | combined_all | State average SAT total score in 2017                              |
# | act17_participation   | float64 | 0-1        | combined_all | State ACT participation rate in 2017                               |
# | act17_english         | float64 | 1-36       | combined_all | State average ACT English score in 2017                            |
# | act17_math            | float64 | 1-36       | combined_all | State average ACT Math score in 2017                               |
# | act17_reading         | float64 | 1-36       | combined_all | State average ACT Reading score in 2017                            |
# | act17_science         | float64 | 1-36       | combined_all | State average ACT Science score in 2017                            |
# | act17_composite       | float64 | 1-36       | combined_all | State average ACT Composite score in 2017                          |
# | sat18_participation   | float64 | 0-1        | combined_all | State SAT participation rate in 2018                               |
# | sat18_reading_writing | int64   | 200-800    | combined_all | State average SAT Evidence-Based Reading and Writing score in 2018 |
# | sat18_math            | int64   | 200-800    | combined_all | State average SAT Math score in 2018                               |
# | sat18_total           | int64   | 400-1600   | combined_all | State average SAT total score in 2018                              |
# | act18_participation   | float64 | 0-1        | combined_all | State ACT participation rate in 2018                               |
# | act18_composite       | float64 | 1-36       | combined_all | State average ACT Composite score in 2018                          |
# | sat19_participation   | float64 | 0-1        | combined_all | State SAT participation rate in 2019                               |
# | sat19_reading_writing | int64   | 200-800    | combined_all | State average SAT Evidence-Based Reading and Writing in 2019       |
# | sat19_math            | int64   | 200-800    | combined_all | State average SAT Math score in 2019                               |
# | sat19_total           | int64   | 400-1600   | combined_all | State average SAT total score in 2019                              |
# | act19_participation   | float64 | 0-1        | combined_all | State ACT participation rate in 2019                               |
# | act19_composite       | float64 | 1-36       | combined_all | State average ACT Composite score in 2019                          |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### 1. Summary Statistics

# %%
#We can transpose the output for the describe method to have a better overview of the summary statistics
combined_all.describe().T
# Out:
#                        count         mean        std     min        25%  \
# sat17_participation     52.0     0.408654   0.357579    0.02     0.0400
# sat17_reading_writing   52.0   568.038462  45.881758  482.00   531.7500
# sat17_math              52.0   555.769231  47.342563  468.00   522.5000
# sat17_total             52.0  1123.903846  92.940263  950.00  1054.2500
# act17_participation     52.0     0.641538   0.327997    0.08     0.3100
# act17_english           52.0    20.994231   2.374159   16.30    19.0000
# act17_math              52.0    21.236538   2.000983   18.00    19.4000
# act17_reading           52.0    22.067308   2.083052   18.10    20.4750
# act17_science           52.0    21.494231   1.750228   18.20    19.9750
# act17_composite         52.0    21.573077   2.037599   17.80    19.8000
# sat18_participation     52.0     0.467692   0.376775    0.02     0.0475
# sat18_reading_writing   52.0   562.692308  47.577610  480.00   530.5000
# sat18_math              52.0   555.173077  47.918117  480.00   521.7500
# sat18_total             52.0  1117.961538  94.401305  977.00  1047.7500
# act18_participation     52.0     0.606731   0.345456    0.07     0.2700
# act18_composite         52.0    21.544231   2.119417   17.70    19.9750
# sat19_participation     52.0     0.500192   0.389859    0.02     0.0575
# sat19_reading_writing   52.0   559.865385  46.289807  483.00   524.0000
# sat19_math              52.0   551.230769  51.260050  460.00   506.7500
# sat19_total             52.0  1111.153846  97.235793  943.00  1028.5000
# act19_participation     52.0     0.576538   0.349475    0.06     0.2375
# act19_composite         52.0    21.519231   2.208188   17.90    19.8000
#
#                             50%        75%     max
# sat17_participation       0.405     0.6750     1.0
# sat17_reading_writing   558.500   612.5000   644.0
# sat17_math              544.500   597.0000   651.0
# sat17_total            1104.500  1210.0000  1295.0
# act17_participation       0.680     1.0000     1.0
# act17_english            20.800    23.3250    25.5
# act17_math               21.050    23.1500    25.3
# act17_reading            21.850    24.2000    26.0
# act17_science            21.400    23.2000    24.9
# act17_composite          21.400    23.6250    25.5
# sat18_participation       0.535     0.7925     1.0
# sat18_reading_writing   551.000   608.2500   643.0
# sat18_math              543.500   592.7500   655.0
# sat18_total            1096.000  1201.0000  1298.0
# act18_participation       0.655     1.0000     1.0
# act18_composite          21.300    23.7250    25.6
# sat19_participation       0.585     0.8500     1.0
# sat19_reading_writing   550.000   611.0000   636.0
# sat19_math              545.500   597.5000   648.0
# sat19_total            1097.000  1205.0000  1284.0
# act19_participation       0.515     1.0000     1.0
# act19_composite          21.150    23.8500    25.5

# %% [markdown]
# ### 2. Apply standard deviation funtion to each numeric column in dataframe

# %%
#list of numeric columns is all the columns except for state columns:
num_columns = combined_all.columns[1:]
num_columns
# Out:
# Index(['sat17_participation', 'sat17_reading_writing', 'sat17_math',
#        'sat17_total', 'act17_participation', 'act17_english', 'act17_math',
#        'act17_reading', 'act17_science', 'act17_composite',
#        'sat18_participation', 'sat18_reading_writing', 'sat18_math',
#        'sat18_total', 'act18_participation', 'act18_composite',
#        'sat19_participation', 'sat19_reading_writing', 'sat19_math',
#        'sat19_total', 'act19_participation', 'act19_composite'],
#       dtype='object')

# %%
sd = {col : calculate_std(combined_all[col]) for col in num_columns}
sd
# Out:
# {'sat17_participation': 0.3541242114012988,
#  'sat17_reading_writing': 45.43844591162758,
#  'sat17_math': 46.88513598499381,
#  'sat17_total': 92.0422686377098,
#  'act17_participation': 0.324827673931085,
#  'act17_english': 2.351220097469729,
#  'act17_math': 1.9816493563689903,
#  'act17_reading': 2.06292558815109,
#  'act17_science': 1.7333175683928808,
#  'act17_composite': 2.017911657040839,
#  'sat18_participation': 0.3731344126998051,
#  'sat18_reading_writing': 47.117912020123455,
#  'sat18_math': 47.455129071028026,
#  'sat18_total': 93.48919343935334,
#  'act18_participation': 0.3421185194650338,
#  'act18_composite': 2.098938693495657,
#  'sat19_participation': 0.38609230853522475,
#  'sat19_reading_writing': 45.84255196873225,
#  'sat19_math': 50.764772531525395,
#  'sat19_total': 96.29629448406075,
#  'act19_participation': 0.34609849984886265,
#  'act19_composite': 2.1868521864102073}

# %%
#Finding the degree of freedom for Pandas .describe() method:
sd1 = {col : np.std(combined_all[col], ddof=1) for col in num_columns}
sd1
# Out:
# {'sat17_participation': 0.35757916357110514,
#  'sat17_reading_writing': 45.88175832077858,
#  'sat17_math': 47.34256277787541,
#  'sat17_total': 92.94026325515038,
#  'act17_participation': 0.32799679945464205,
#  'act17_english': 2.374159373339347,
#  'act17_math': 2.000982978649405,
#  'act17_reading': 2.083052168055718,
#  'act17_science': 1.7502283841492658,
#  'act17_composite': 2.0375990662422114,
#  'sat18_participation': 0.376774834640133,
#  'sat18_reading_writing': 47.57760985249278,
#  'sat18_math': 47.91811690375374,
#  'sat18_total': 94.40130473061073,
#  'act18_participation': 0.34545634015930204,
#  'act18_composite': 2.119416629089746,
#  'sat19_participation': 0.3898591519652203,
#  'sat19_reading_writing': 46.28980696936351,
#  'sat19_math': 51.26005033338336,
#  'sat19_total': 97.23579277550911,
#  'act19_participation': 0.34947515053955636,
#  'act19_composite': 2.2081878349290878}

# %% [markdown]
# Comment: Pandas .describe() method uses ddof = 1, thus there is the difference in solution compared to my calculate_std function

# %% [markdown]
# ### 3. Investigate trends in data

# %%
#need to remove duplicate rows for state 'Maine':
combined_all = combined_all.drop_duplicates()

# %% [markdown]
# #### Highest and Lowest SAT Participation Rates 2017, 2018, 2019

# %%
#States with the highest 2017 SAT participation rate:
combined_all.loc[:, ['state', 'sat17_participation']]\
                 .sort_values(by='sat17_participation', ascending=False).head()
# Out:
#                    state  sat17_participation
# 8   District of Columbia                 1.00
# 23              Michigan                 1.00
# 6            Connecticut                 1.00
# 7               Delaware                 1.00
# 30         New Hampshire                 0.96

# %%
#States with the lowest 2017 SAT participation rate:
combined_all.loc[:, ['state', 'sat17_participation']]\
                 .sort_values(by='sat17_participation').head()
# Out:
#            state  sat17_participation
# 35  North Dakota                 0.02
# 25   Mississippi                 0.02
# 15          Iowa                 0.02
# 26      Missouri                 0.03
# 45          Utah                 0.03

# %%
#States with the highest 2018 SAT participation rate:
combined_all.loc[:, ['state','sat18_participation']]\
                 .sort_values(by='sat18_participation', ascending=False).head()
# Out:
#           state  sat18_participation
# 5      Colorado                  1.0
# 6   Connecticut                  1.0
# 7      Delaware                  1.0
# 23     Michigan                  1.0
# 12        Idaho                  1.0

# %%
#States with the lowest 2018 SAT participation rate:
combined_all.loc[:, ['state', 'sat18_participation']]\
                 .sort_values(by='sat18_participation').head()
# Out:
#            state  sat18_participation
# 35  North Dakota                 0.02
# 51       Wyoming                 0.03
# 42  South Dakota                 0.03
# 28      Nebraska                 0.03
# 50     Wisconsin                 0.03

# %%
#States with the highest 2019 SAT participation rate:
combined_all.loc[:, ['state', 'sat19_participation']]\
                .sort_values(by='sat19_participation', ascending=False).head()
# Out:
#            state  sat19_participation
# 40  Rhode Island                  1.0
# 13      Illinois                  1.0
# 23      Michigan                  1.0
# 5       Colorado                  1.0
# 6    Connecticut                  1.0

# %%
#States with the lowest 2019 SAT participation rate:
combined_all.loc[:, ['state', 'sat19_participation']]\
                 .sort_values(by='sat19_participation').head()
# Out:
#            state  sat19_participation
# 35  North Dakota                 0.02
# 51       Wyoming                 0.03
# 42  South Dakota                 0.03
# 28      Nebraska                 0.03
# 50     Wisconsin                 0.03

# %% [markdown]
# #### Highest and Lowest ACT Participation Rates 2017, 2018, 2019

# %%
#States with the highest 2017 ACT participation rate:
combined_all.loc[:, ['state', 'act17_participation']]\
                .sort_values(by='act17_participation', ascending=False).head()
# Out:
#         state  act17_participation
# 0     Alabama                  1.0
# 17   Kentucky                  1.0
# 50  Wisconsin                  1.0
# 45       Utah                  1.0
# 43  Tennessee                  1.0

# %%
#States with the lowest 2017 ACT participation rate:
combined_all.loc[:, ['state', 'act17_participation']]\
                 .sort_values(by='act17_participation').head()
# Out:
#             state  act17_participation
# 19          Maine                 0.08
# 30  New Hampshire                 0.18
# 7        Delaware                 0.18
# 40   Rhode Island                 0.21
# 39   Pennsylvania                 0.23

# %%
#States with the highest 2018 ACT participation rate:
combined_all.loc[:, ['state', 'act18_participation']]\
                .sort_values(by='act18_participation', ascending=False).head()
# Out:
#         state  act18_participation
# 0     Alabama                  1.0
# 17   Kentucky                  1.0
# 50  Wisconsin                  1.0
# 45       Utah                  1.0
# 43  Tennessee                  1.0

# %%
#States with the lowest 2018 ACT participation rate:
combined_all.loc[:, ['state', 'act18_participation']]\
                 .sort_values(by='act18_participation').head()
# Out:
#             state  act18_participation
# 19          Maine                 0.07
# 40   Rhode Island                 0.15
# 30  New Hampshire                 0.16
# 7        Delaware                 0.17
# 39   Pennsylvania                 0.20

# %%
#States with the highest 2019 ACT participation rate:
combined_all.loc[:, ['state', 'act19_participation']]\
                .sort_values(by='act19_participation', ascending=False).head()
# Out:
#         state  act19_participation
# 0     Alabama                  1.0
# 17   Kentucky                  1.0
# 50  Wisconsin                  1.0
# 45       Utah                  1.0
# 43  Tennessee                  1.0

# %%
#States with the lowest 2019 ACT participation rate:
combined_all.loc[:, ['state', 'act19_participation']]\
                 .sort_values(by='act19_participation').head()
# Out:
#             state  act19_participation
# 19          Maine                 0.06
# 40   Rhode Island                 0.12
# 7        Delaware                 0.13
# 30  New Hampshire                 0.14
# 39   Pennsylvania                 0.17

# %% [markdown]
# #### Highest and Lowest  Mean SAT Total Scores for the year 2017, 2018, 2019

# %%
#We are using Boolean filtering to filter the highest total scores by states that are above the 90% quantile
#Then we sort the value by total
combined_all[combined_all['sat17_total'] > combined_all['sat17_total'].quantile(0.9)]\
             .sort_values('sat17_total', ascending=False)['state'].head()
# Out:
# 24    Minnesota
# 50    Wisconsin
# 15         Iowa
# 26     Missouri
# 16       Kansas
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the lowest total scores by states that are below the 10% quantile
#Then we sort the value by total
combined_all[combined_all['sat17_total'] < combined_all['sat17_total'].quantile(0.1)]\
             .sort_values('sat17_total')['state'].head()
# Out:
# 8     District of Columbia
# 7                 Delaware
# 12                   Idaho
# 23                Michigan
# 19                   Maine
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the highest total scores by states that are above the 90% quantile
#Then we sort the value by total
combined_all[combined_all['sat18_total'] > combined_all['sat18_total'].quantile(0.9)]\
             .sort_values('sat18_total', ascending=False)['state'].head()
# Out:
# 24       Minnesota
# 50       Wisconsin
# 35    North Dakota
# 15            Iowa
# 16          Kansas
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the lowest total scores by states that are below the 10% quantile
#Then we sort the value by total
combined_all[combined_all['sat18_total'] < combined_all['sat18_total'].quantile(0.1)]\
             .sort_values('sat18_total')['state'].head()
# Out:
# 8     District of Columbia
# 7                 Delaware
# 49           West Virginia
# 12                   Idaho
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the highest total scores by states that are above the 90% quantile
#Then we sort the value by total
combined_all[combined_all['sat19_total'] > combined_all['sat19_total'].quantile(0.9)]\
             .sort_values('sat19_total', ascending=False)['state'].head()
# Out:
# 24       Minnesota
# 50       Wisconsin
# 42    South Dakota
# 35    North Dakota
# 28        Nebraska
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the lowest total scores by states that are below the 10% quantile
#Then we sort the value by total
combined_all[combined_all['sat19_total'] < combined_all['sat19_total'].quantile(0.1)]\
             .sort_values('sat19_total')['state'].head()
# Out:
# 49           West Virginia
# 37                Oklahoma
# 8     District of Columbia
# 7                 Delaware
# 12                   Idaho
# Name: state, dtype: object

# %% [markdown]
# #### Highest and Lowest  Mean  ACT Composite Scores for the year 2017, 2018, 2019

# %%
#We are using Boolean filtering to filter the highest composite scores by states that are above the 90% quantile
#Then we sort the value by total
combined_all[combined_all['act17_composite'] > combined_all['act17_composite'].quantile(0.9)]\
             .sort_values('act17_composite', ascending=False)['state'].head()
# Out:
# 30    New Hampshire
# 22    Massachusetts
# 6       Connecticut
# 19            Maine
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the lowest composite scores by states that are below the 10% quantile
#Then we sort the value by total
combined_all[combined_all['act17_composite'] < combined_all['act17_composite'].quantile(0.1)]\
             .sort_values('act17_composite')['state'].head()
# Out:
# 29            Nevada
# 25       Mississippi
# 41    South Carolina
# 11            Hawaii
# 34    North Carolina
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the highest composite scores by states that are above the 90% quantile
#Then we sort the value by total
combined_all[combined_all['act18_composite'] > combined_all['act18_composite'].quantile(0.9)]\
             .sort_values('act18_composite', ascending=False)['state'].head()
# Out:
# 6       Connecticut
# 22    Massachusetts
# 30    New Hampshire
# 33         New York
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the lowest composite scores by states that are below the 10% quantile
#Then we sort the value by total
combined_all[combined_all['act18_composite'] < combined_all['act18_composite'].quantile(0.1)]\
             .sort_values('act18_composite')['state'].head()
# Out:
# 29            Nevada
# 41    South Carolina
# 25       Mississippi
# 11            Hawaii
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the highest composite scores by states that are above the 90% quantile
#Then we sort the value by total
combined_all[combined_all['act19_composite'] > combined_all['act19_composite'].quantile(0.9)]\
             .sort_values('act19_composite', ascending=False)['state'].head()
# Out:
# 6       Connecticut
# 22    Massachusetts
# 30    New Hampshire
# 40     Rhode Island
# 33         New York
# Name: state, dtype: object

# %%
#We are using Boolean filtering to filter the lowest composite scores by states that are below the 10% quantile
#Then we sort the value by total
combined_all[combined_all['act19_composite'] < combined_all['act19_composite'].quantile(0.1)]\
             .sort_values('act19_composite')['state'].head()
# Out:
# 29            Nevada
# 25       Mississippi
# 18         Louisiana
# 41    South Carolina
# Name: state, dtype: object

# %% [markdown]
# #### Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
#States with 100% SAT participation rates in either year 2017 or 2018 or 2019
combined_all[(combined_all['sat17_participation'] == 1) | 
             (combined_all['sat18_participation'] == 1) | \
             (combined_all['sat19_participation'] == 1)]  \
            [['state','sat17_participation','sat18_participation', 'sat19_participation']]
# Out:
#                    state  sat17_participation  sat18_participation  \
# 5               Colorado                 0.11                 1.00
# 6            Connecticut                 1.00                 1.00
# 7               Delaware                 1.00                 1.00
# 8   District of Columbia                 1.00                 0.92
# 9                Florida                 0.83                 0.56
# 12                 Idaho                 0.93                 1.00
# 13              Illinois                 0.09                 0.99
# 23              Michigan                 1.00                 1.00
# 40          Rhode Island                 0.71                 0.97
#
#     sat19_participation
# 5                  1.00
# 6                  1.00
# 7                  1.00
# 8                  0.94
# 9                  1.00
# 12                 1.00
# 13                 1.00
# 23                 1.00
# 40                 1.00

# %%
#States with 100% SAT participation rates from year 2017 to 2019:
combined_all[(combined_all['sat17_participation'] == 1) & 
             (combined_all['sat18_participation'] == 1) & \
             (combined_all['sat19_participation'] == 1)]  \
            [['state','sat17_participation','sat18_participation', 'sat19_participation']]
# Out:
#           state  sat17_participation  sat18_participation  sat19_participation
# 6   Connecticut                  1.0                  1.0                  1.0
# 7      Delaware                  1.0                  1.0                  1.0
# 23     Michigan                  1.0                  1.0                  1.0

# %%
#States with 100% ACT participation rates in either year 2017 or 2018 or 2019
combined_all[(combined_all['act17_participation'] == 1) | 
             (combined_all['act18_participation'] == 1) | \
             (combined_all['act19_participation'] == 1)]  \
            [['state','act17_participation','act18_participation', 'act19_participation']]
# Out:
#              state  act17_participation  act18_participation  \
# 0          Alabama                 1.00                 1.00
# 3         Arkansas                 1.00                 1.00
# 5         Colorado                 1.00                 0.30
# 17        Kentucky                 1.00                 1.00
# 18       Louisiana                 1.00                 1.00
# 24       Minnesota                 1.00                 0.99
# 25     Mississippi                 1.00                 1.00
# 26        Missouri                 1.00                 1.00
# 27         Montana                 1.00                 1.00
# 28        Nebraska                 0.84                 1.00
# 29          Nevada                 1.00                 1.00
# 34  North Carolina                 1.00                 1.00
# 36            Ohio                 0.75                 1.00
# 37        Oklahoma                 1.00                 1.00
# 41  South Carolina                 1.00                 1.00
# 43       Tennessee                 1.00                 1.00
# 45            Utah                 1.00                 1.00
# 50       Wisconsin                 1.00                 1.00
# 51         Wyoming                 1.00                 1.00
#
#     act19_participation
# 0                  1.00
# 3                  1.00
# 5                  0.27
# 17                 1.00
# 18                 1.00
# 24                 0.95
# 25                 1.00
# 26                 0.82
# 27                 1.00
# 28                 1.00
# 29                 1.00
# 34                 1.00
# 36                 1.00
# 37                 1.00
# 41                 0.78
# 43                 1.00
# 45                 1.00
# 50                 1.00
# 51                 1.00

# %%
#States with 100% ACT participation rates in from year 2017 to 2019
combined_all[(combined_all['act17_participation'] == 1) & 
             (combined_all['act18_participation'] == 1) & \
             (combined_all['act19_participation'] == 1)]  \
            [['state','act17_participation','act18_participation', 'act19_participation']]
# Out:
#              state  act17_participation  act18_participation  \
# 0          Alabama                  1.0                  1.0
# 3         Arkansas                  1.0                  1.0
# 17        Kentucky                  1.0                  1.0
# 18       Louisiana                  1.0                  1.0
# 25     Mississippi                  1.0                  1.0
# 27         Montana                  1.0                  1.0
# 29          Nevada                  1.0                  1.0
# 34  North Carolina                  1.0                  1.0
# 37        Oklahoma                  1.0                  1.0
# 43       Tennessee                  1.0                  1.0
# 45            Utah                  1.0                  1.0
# 50       Wisconsin                  1.0                  1.0
# 51         Wyoming                  1.0                  1.0
#
#     act19_participation
# 0                   1.0
# 3                   1.0
# 17                  1.0
# 18                  1.0
# 25                  1.0
# 27                  1.0
# 29                  1.0
# 34                  1.0
# 37                  1.0
# 43                  1.0
# 45                  1.0
# 50                  1.0
# 51                  1.0

# %% [markdown]
# **Answer:**
# - Illinois has the highest increase in SAT participation rate from 9% in sat_2017 to 99% in sat_2018 followed by 100% in sat_2019.
# - Colorado has the second highest increase in SAT participation rate from 11% in sat_2017 to 100% in sat_2018 followed by 100% in sat_2019. This happens concurrently with ACT participation rate that is decreasing significantly from 100% in act_2017 to 30% in act_2018 followed by 27% in act_2019.
# - Connecticut, Delaware and Michigan remains to have 100% SAT participation rates from 2017 to 2019.
# - There are 13 states having 100% ACT participation rates from 2017 to 2019.

# %% [markdown]
# #### Do any states show have >50% participation on both tests each year?

# %%
#We use boolean filtering to show the any states that have >50% participation rates on sat_2017 and act_2017
combined_all[(combined_all['sat17_participation'] >= 0.5) & (combined_all['act17_participation'] >= 0.5)]\
            [['state', 'sat17_participation', 'act17_participation']]
# Out:
#              state  sat17_participation  act17_participation
# 9          Florida                 0.83                 0.73
# 10         Georgia                 0.61                 0.55
# 11          Hawaii                 0.55                 0.90
# 41  South Carolina                 0.50                 1.00

# %%
#We use boolean filtering to show the any states that have >50% participation rates on sat_2018 and act_2018
combined_all[(combined_all['sat18_participation'] >= 0.5) & (combined_all['act18_participation'] >= 0.5)]\
            [['state', 'sat18_participation', 'act18_participation']]
# Out:
#              state  sat18_participation  act18_participation
# 9          Florida                 0.56                 0.66
# 10         Georgia                 0.70                 0.53
# 11          Hawaii                 0.56                 0.89
# 34  North Carolina                 0.52                 1.00
# 41  South Carolina                 0.55                 1.00

# %%
#We use boolean filtering to show the any states that have >50% participation rates on sat_2019 and act_2019
combined_all[(combined_all['sat19_participation'] >= 0.5) & (combined_all['act19_participation'] >= 0.5)]\
            [['state', 'sat19_participation', 'act19_participation']]
# Out:
#              state  sat19_participation  act19_participation
# 9          Florida                 1.00                 0.54
# 11          Hawaii                 0.54                 0.80
# 34  North Carolina                 0.51                 1.00
# 41  South Carolina                 0.68                 0.78

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# ### 1. Use Seaborn's heatmap with pandas .corr() to visualize correlations between all numeric features

# %%
# Establish size of figure.
plt.figure(figsize = (16,12))

# Get correlation of variables.
corr = combined_all.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)
    
#Name the title:
plt.title('Correlation Heatmap', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# **Interpretation:**
#
# - **SAT and ACT participation have a strong negative correlation** <br>
#
# - **Participation and total/composite score have a strong negative correlation** <br>
#
# - **There is a strong positive correlation on year on year participation** <br>

# %% [markdown]
# ### 2. Visualize distributions using histograms

# %% [markdown]
# ### SAT and ACT Participation Rates

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    # Makes sure you have enough rows
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    
    # You'll want to specify your figsize
    fig, ax = plt.subplots(nrows=nrows, ncols=2, sharex=False, sharey=True, squeeze=True, figsize=(20,20)) 
    
    # Ravel turns a matrix into a vector, which is easier to iterate
    ax = ax.ravel() 
    
    # Gives us an index value to get into all our lists
    for i, column in enumerate(list_of_columns): 
        ax[i].hist(dataframe[column])
        ax[i].set_title(list_of_titles[i], fontsize = 20)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize = 17)# Set titles, labels, etc here for each subplot
        ax[i].set_ylabel(list_of_ylabels[i], fontsize = 17)
        ax[i].axvline(dataframe[column].median(), color='r', linestyle='dashed', linewidth=3, label='median')
        ax[i].axvline(dataframe[column].mean(), color='k', linestyle='dashed', linewidth=3, label = 'mean')
        ax[i].legend()

# %%
#Define the variable to input to subplot_histograms:
list_of_columns = ['sat17_participation', 'act17_participation', 'sat18_participation', 
                    'act18_participation', 'sat19_participation', 'act19_participation']
list_of_titles = ['2017 SAT Participation','2017 ACT Participation', '2018 SAT Participation', 
                   '2018 ACT Participation', '2019 SAT Participation','2019 ACT Participation']
list_of_xlabels = ['State Participation']*6
list_of_ylabels = ['Frequency']*6

#Plot the histograms:
subplot_histograms(combined_all, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels)

# %% [markdown]
# **Interpretation:**
# - There seems to be a negative relationship between SAT and ACT participation rates in a given year.<br>
# When there is a high frequency of 100% ACT participation rate, there is a low frequency of 100% SAT participation rate in a given year.
#
# - There are more states having 100% participation rate for ACT compared to SAT.
#
# - The Central Limit Theorem states that by summing the random independent variables, the sums will tend towards a random normal distribution. <br>
# However, we do not observe this trend here. The reason might be that the states that we sample are not random, they are already divided geographically. This might have an impact on estimations derived from this data to be beyond the actual population's expected range of values.

# %%
combined_all.head()
# Out:
#         state  sat17_participation  sat17_reading_writing  sat17_math  \
# 0     Alabama                 0.05                    593         572
# 1      Alaska                 0.38                    547         533
# 2     Arizona                 0.30                    563         553
# 3    Arkansas                 0.03                    614         594
# 4  California                 0.53                    531         524
#
#    sat17_total  act17_participation  act17_english  act17_math  act17_reading  \
# 0         1165                 1.00           18.9        18.4           19.7
# 1         1080                 0.65           18.7        19.8           20.4
# 2         1116                 0.62           18.6        19.8           20.1
# 3         1208                 1.00           18.9        19.0           19.7
# 4         1055                 0.31           22.5        22.7           23.1
#
#    act17_science  ...  sat18_math  sat18_total  act18_participation  \
# 0           19.4  ...         571         1166                 1.00
# 1           19.9  ...         544         1106                 0.33
# 2           19.8  ...         572         1149                 0.66
# 3           19.5  ...         576         1169                 1.00
# 4           22.2  ...         536         1076                 0.27
#
#    act18_composite  sat19_participation  sat19_reading_writing  sat19_math  \
# 0             19.1                 0.07                    583         560
# 1             20.8                 0.41                    556         541
# 2             19.2                 0.31                    569         565
# 3             19.4                 0.06                    582         559
# 4             22.7                 0.63                    534         531
#
#    sat19_total  act19_participation  act19_composite
# 0         1143                 1.00             18.9
# 1         1097                 0.38             20.1
# 2         1134                 0.73             19.0
# 3         1141                 1.00             19.3
# 4         1065                 0.23             22.6
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 3. Plot and interpret boxplots

# %% [markdown]
# ### Participation Rate

# %%
#Plotting SAT and ACT participation rates for 2017,2018, 2019
plt.figure(figsize=(20,10))

#Plotting boxplot
sns.boxplot(data=combined_all.loc[:,['sat17_participation','sat18_participation', 'sat19_participation',
                              'act17_participation','act18_participation', 'act19_participation']]
           ).tick_params(labelsize = 15) #tick.params for xlabel size
#Setting the title
plt.title('SAT and ACT participation rates in 2017-2019', fontsize=24)

#Setting ylabel
plt.ylabel('Participation rate',fontsize=15);

# %%
#find the median of the participation rates in all years:
combined_all.describe().loc['50%'][['sat17_participation', 'sat18_participation', 'sat19_participation',
                                    'act17_participation', 'act18_participation', 'act19_participation'  ]]
# Out:
# sat17_participation    0.38
# sat18_participation    0.52
# sat19_participation    0.54
# act17_participation    0.69
# act18_participation    0.66
# act19_participation    0.54
# Name: 50%, dtype: float64

# %% [markdown]
# **Comment:**
#
# Participation rate for ACT has a higher median than the SAT for the year 2017 and 2018. However, there is a decreasing trend for ACT participation rate from 69% in 2017 to 54% in 2019. On the other hand, there is an increasing trend in SAT participation rate from 38% in 2017 to 54% in 2019.

# %% [markdown]
# ### SAT Total Score

# %%
#Plotting SAT and ACT participation rates for 2017,2018, 2019
plt.figure(figsize=(7,5))

#Plotting boxplot
sns.boxplot(data=combined_all.loc[:,['sat17_total','sat18_total', 'sat19_total']]
           ).tick_params(labelsize = 15) #tick.params for xlabel size
#Setting the title
plt.title('SAT Total Score in 2017-2019', fontsize=18)

#Setting ylabel
plt.ylabel('Score',fontsize=15);

# %%
#summary statistics:
combined_all.describe().loc[['min','25%','50%','75%','max']][['sat17_total', 'sat18_total', 'sat19_total']]
# Out:
#      sat17_total  sat18_total  sat19_total
# min        950.0        977.0        943.0
# 25%       1055.5       1057.5       1038.0
# 50%       1107.0       1098.0       1097.0
# 75%       1212.0       1204.0       1210.0
# max       1295.0       1298.0       1284.0

# %% [markdown]
# **Comment:**
# There is a decreasing trend in median score, also the lower and upper whisker shift downwards from 2017 to 2019.

# %% [markdown]
# ### ACT Composite Score

# %%
#Plotting ACT Composite Score for 2017,2018, 2019
plt.figure(figsize=(7,5))

#Plotting boxplot
sns.boxplot(data=combined_all.loc[:,['act17_composite','act18_composite', 'act19_composite']]
           ).tick_params(labelsize = 15) #tick.params for xlabel size
#Setting the title
plt.title('ACT Composite Score in 2017-2019', fontsize=18)

#Setting ylabel
plt.ylabel('Score',fontsize=15);

# %%
#summary statistics:
combined_all.describe().loc[['min','25%','50%','75%','max']][['act17_composite', 'act18_composite', 'act19_composite']]
# Out:
#      act17_composite  act18_composite  act19_composite
# min             17.8            17.70             17.9
# 25%             19.8            19.95             19.8
# 50%             21.4            21.30             21.1
# 75%             23.6            23.65             23.7
# max             25.5            25.60             25.5

# %% [markdown]
# **Comment:** There is a slight decreasing trend in median score, but overall there is little change in composite score throughout the years.

# %% [markdown]
# ### 4. Plot and interpret scatter plots to view relationships between features

# %%
def scatter_plot(dataframe, title, xaxis, yaxis, xlabel, ylabel):

    plt.figure(figsize = (16, 9))

    # Create scatterplot:
    sns.regplot(data=dataframe, x=xaxis, y=yaxis)  
    
    #Setting the title:
    plt.title(title, fontsize = 20)
    
    #Setting the label for x and y axis:
    plt.xlabel(xlabel, fontsize = 18)
    plt.ylabel(ylabel, fontsize = 18);

# %%
scatter_plot(combined_all,'SAT 2017 Participation Rate vs Total Score', 'sat17_participation', 'sat17_total',
             '2017 SAT Participation', '2017 SAT Total Score')

# %%
scatter_plot(combined_all,'SAT 2018 Participation Rate vs Total Score', 'sat18_participation', 'sat18_total',
             '2018 SAT Participation', '2018 SAT Total Score')

# %%
scatter_plot(combined_all,'SAT 2019 Participation Rate vs Total Score', 'sat19_participation', 'sat19_total',
             '2019 SAT Participation', '2019 SAT Total Score')

# %% [markdown]
# **Interpretation:** <br>
# There is a negative relationship between SAT participation rate and total score. <br>
# The higher the participation rate, the lower is the total score.

# %% [markdown]
# ### Findings from data and outside research

# %% [markdown]
# ### Overall Participation Rate

# %%
scatter_plot(combined_all,'SAT 2017 vs 2018 Participation Rate', 'sat17_participation', 'sat18_participation',
             '2017 SAT Participation', '2018 SAT Participation')

# %%
#There are 2 outliers in the 2017 vs 2018 Participation Rates:
combined_all[(combined_all['sat17_participation']<0.2)&(combined_all['sat18_participation']>0.8)] \
              [['state','sat17_participation','sat18_participation']]
# Out:
#        state  sat17_participation  sat18_participation
# 5   Colorado                 0.11                 1.00
# 13  Illinois                 0.09                 0.99

# %% [markdown]
# ### Colorado

# %%
combined_all[combined_all['state']=='Colorado'] \
             [['state','sat17_participation', 'sat17_total', 
               'act17_participation', 'act17_composite',
               'sat18_participation', 'sat18_total',
              'act18_participation', 'act18_composite']].T
# Out:
#                             5
# state                Colorado
# sat17_participation      0.11
# sat17_total              1201
# act17_participation       1.0
# act17_composite          20.8
# sat18_participation       1.0
# sat18_total              1025
# act18_participation       0.3
# act18_composite          23.9

# %% [markdown]
# - According to the data, SAT participation increased from 11% in 2017 to 100% in 2018. While on the other hand, ACT participation decreased from 100% in 2017 to 30% in 2018. <br>
#
# - Colorado's SAT 2017 participation rate has increased very significantly as a result of the mandatory requirement for students to take the SAT exam [(Source)](https://testive.com/colorado-sat-change-2017/). The increase in participation rates is also because the fee for the mandatory testing had been made free of charge. Moreover, Khan Academy and the College Board have collaborated to offer free access to official SAT study materials. However, Khan Academy might not be a very succesful approach to prepare the students well for the SAT as there is a significant decrease in SAT total score from 1201  to 1025.

# %% [markdown]
# ### Illinois

# %%
combined_all[combined_all['state']=='Illinois'] \
             [['state','sat17_participation', 'sat17_total', 
               'act17_participation', 'act17_composite',
               'sat18_participation', 'sat18_total',
              'act18_participation', 'act18_composite']].T
# Out:
#                            13
# state                Illinois
# sat17_participation      0.09
# sat17_total              1115
# act17_participation      0.93
# act17_composite          21.4
# sat18_participation      0.99
# sat18_total              1019
# act18_participation      0.43
# act18_composite          23.9

# %% [markdown]
# The data shows a significant increase in SAT participation rate from 9% in 2017 to 99% in 2018.
# On the other hand, as the state contract for ACT exam has expired, the ACT participation rate has dropped from 93% to 43% in 2018.
# Thus, in place of the ACT test, mandatory SAT testing was implemented in Illinois in 2016[(Source)](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html). Along with this, personalized online test practice through Khan Academy and college application fee waivers were also offered. However, there is still a drop in SAT score from 1115 to 1019.

# %%
scatter_plot(combined_all,'SAT 2018 vs 2019 Participation Rate', 'sat18_participation', 'sat19_participation',
             '2018 SAT Participation', '2019 SAT Participation')

# %%
#There are 2 outliers in the 2018 vs 2019 Participation Rates:
combined_all[(combined_all['sat18_participation']<0.6)&(combined_all['sat19_participation']>0.8)] \
            [['state','sat18_participation','sat19_participation']]
# Out:
#             state  sat18_participation  sat19_participation
# 9         Florida                 0.56                 1.00
# 49  West Virginia                 0.28                 0.99

# %% [markdown]
# ### Florida

# %%
combined_all[combined_all['state']=='Florida'] \
             [['state','sat18_participation', 'sat18_total', 
               'act18_participation', 'act18_composite',
               'sat19_participation', 'sat19_total',
              'act19_participation', 'act19_composite']].T
# Out:
#                            9
# state                Florida
# sat18_participation     0.56
# sat18_total             1099
# act18_participation     0.66
# act18_composite         19.9
# sat19_participation      1.0
# sat19_total              999
# act19_participation     0.54
# act19_composite         20.1

# %% [markdown]
# There is a significant increase in SAT participation rate from 56% in 2018 to 100% in 2017.
# The increase in test takers is partly attributable to "SAT school day" programs, which let students take the test for free during the week at their school[(Source)](https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html).
# These programs are now available in many Florida school districts and they have helped the SAT become more popular than the ACT.
# However, there is a drop in the SAT total score from 1099 in 2018 to 999 in 2019. This is partly because many of the test takers come from low income families or from families with no history of attending college.

# %% [markdown]
# ### West Virginia

# %%
combined_all[combined_all['state']=='West Virginia'] \
             [['state','sat18_participation', 'sat18_total', 
               'act18_participation', 'act18_composite',
               'sat19_participation', 'sat19_total',
              'act19_participation', 'act19_composite']].T
# Out:
#                                 49
# state                West Virginia
# sat18_participation           0.28
# sat18_total                    999
# act18_participation           0.65
# act18_composite               20.3
# sat19_participation           0.99
# sat19_total                    943
# act19_participation           0.49
# act19_composite               20.8

# %% [markdown]
# There is a significant increase in SAT participation rate from 28% in 2018 to 99% in 2017.
# The increase in test takers is partly attributable to "SAT school day" programs, which let students take the test for free during the week at their school[(Source)](https://www.washingtonpost.com/local/education/sat-scores-drop-for-2019-class-but-participation-rises-through-testing-in-schools/2019/09/23/332fc4d0-de11-11e9-8dc8-498eabc129a0_story.html).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ### Key Findings:
#
# - SAT and ACT participation has a strong negative correlation
# - There are more states having a 100% participation rate for ACT compared to SAT
# - Participation and total/composite score have a strong negative correlation
# - There is a strong positive correlation on year on year participation
# - The variables in the dataset are not normally distributed
# - The state mandate, the fee waiver, or the SAT School Day program are the main causes of the rise in SAT participation rates.

# %% [markdown]
# In order to replicate comparable techniques, the College Board should consider the states where SAT participation rates have increased noticeably. Due to the SAT exams becoming mandatory, participation rates in Illinois [(Source)](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html) and Colorado [(Source)](https://testive.com/colorado-sat-change-2017/) have significantly increased. On the other hand, the SAT school day program helped Florida [(Source)](https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html) and West Virginia [(Source)](https://www.washingtonpost.com/local/education/sat-scores-drop-for-2019-class-but-participation-rises-through-testing-in-schools/2019/09/23/332fc4d0-de11-11e9-8dc8-498eabc129a0_story.html) raise their participation rates. Additionally, several states also use Khan Academy as a free study resource and introduce exam fees waiver to attract more test takers.
#
# This dataset also reveals that there is an inverse relationship between participation rates and ACT and SAT scores. While tests with high participation rates, for instance, because of fee waivers, test a lot of students from lower-income families who are unfamiliar with the exam setting or even do not really have a clear plan to enter college, tests with low participation rates test the best students who are well-prepared for the exam.
# In order to adequately prepare students for this exam, the College Board needs to come up with fresh, creative solutions. One such concept is to collaborate with more online learning platforms to help students learn more extensively. To improve execution, a deeper investigation of the effectiveness of the SAT School Day and exam fee waiver is required.
